# %% [markdown]
# # Upload, check and update images on Supabase storage

# %%
import csv
import requests
from pathlib import Path
from collections import defaultdict
import time
from PIL import Image
from io import BytesIO
from tqdm import tqdm
import os
from supabase import create_client
from httpx import RemoteProtocolError, ReadTimeout, WriteError
from dotenv import load_dotenv

# %% [markdown]
# ## Initial image upload

# %%
# CONFIG

SUPABASE_PUBLIC_BASE = (
    "https://utwhgfveotpusdjopcnl.supabase.co"
    "/storage/v1/object/public/prolific_images/"
)

LOCAL_IMAGE_ROOT = Path(
    "/mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data"
)

LOCAL_TABLE_ROOT = Path(
    "/mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/prolific_stimuli"
)

CSV_FILES = [
    "stimulus_table_image_priors.csv",
    "stimulus_table_shapes.csv",
    "stimulus_table_counterfact.csv",
]

TIMEOUT = 10
SLEEP_BETWEEN_REQUESTS = 0.05

# %%
# COLLECT IMAGE PATHS

image_paths = set()
csv_sources = defaultdict(list)

for csv_file in CSV_FILES:
    path = LOCAL_TABLE_ROOT / csv_file
    if not path.exists():
        print(f" CSV not found: {csv_file}")
        continue

    with open(path, newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            img = row["image_path"].strip()
            image_paths.add(img)
            csv_sources[img].append(csv_file)

print(f"\nFound {len(image_paths)} unique image paths\n")
# Out:
# Found 16614 unique image paths

# %%
# CHECK IMAGES

missing_local = []
http_errors = []
ok_images = []

for i, rel_path in enumerate(sorted(image_paths), 1):
    local_path = LOCAL_IMAGE_ROOT / rel_path
    public_url = SUPABASE_PUBLIC_BASE + rel_path

    print(f"[{i}/{len(image_paths)}] Checking {rel_path}")

    # local existence
    if not local_path.exists():
        missing_local.append(rel_path)
        print("   Missing locally")
        continue

    # public URL
    try:
        r = requests.get(public_url, timeout=TIMEOUT)

        if r.status_code != 200:
            http_errors.append((rel_path, r.status_code))
            print(f"   HTTP {r.status_code}")
        else:
            ct = r.headers.get("Content-Type", "")
            if not ct.startswith("image"):
                http_errors.append((rel_path, f"bad content-type: {ct}"))
                print(f"   Bad content-type: {ct}")
            else:
                ok_images.append(rel_path)
                print("   OK")

    except requests.RequestException as e:
        http_errors.append((rel_path, str(e)))
        print(f"   Request error: {e}")

    time.sleep(SLEEP_BETWEEN_REQUESTS)

# SUMMARY

print("\n" + "=" * 60)
print("SUMMARY")
print("=" * 60)

print(f"Total images checked: {len(image_paths)}")
print(f"OK: {len(ok_images)}")
print(f"Missing locally: {len(missing_local)}")
print(f"HTTP / access errors: {len(http_errors)}")

if missing_local:
    print("\n MISSING LOCALLY:")
    for p in missing_local:
        print(f"  - {p} (referenced in {csv_sources[p]})")

if http_errors:
    print("\n PUBLIC ACCESS ERRORS:")
    for p, err in http_errors:
        print(f"  - {p}: {err} (from {csv_sources[p]})")

if not missing_local and not http_errors:
    print("\n All images are present and publicly accessible.")
    print("Likely cause of failures: transient network / CDN issues.")

print("=" * 60)

# %% [markdown]
# ## Check images on Supabase storage

# %%
# Check if all images listed in the stimulus tables can be loaded and decoded from Supabase
image_paths = set()

for csv_file in CSV_FILES:
    with open(LOCAL_TABLE_ROOT / csv_file, newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            image_paths.add(row["image_path"])

print(f"Checking {len(image_paths)} images...\n")


# CHECK IMAGES
errors = []

for path in tqdm(sorted(image_paths)):
    url = SUPABASE_PUBLIC_BASE + path

    try:
        r = requests.get(url, timeout=TIMEOUT)
        if r.status_code != 200:
            errors.append((path, f"HTTP {r.status_code}"))
            continue

        if len(r.content) < 100:
            errors.append((path, "File too small"))
            continue

        # Try decoding image
        img = Image.open(BytesIO(r.content))
        img.verify()  # checks integrity

    except Exception as e:
        errors.append((path, str(e)))


# REPORT
print("\n--- RESULT ---")
if not errors:
    print("All images loaded and decoded successfully.")
else:
    print(f"{len(errors)} problematic images:\n")
    for p, err in errors:
        print(f"{p} → {err}")

    with open("corrupt_images.txt", "w") as f:
        for p, err in errors:
            f.write(f"{p}\t{err}\n")

    print("\nSaved list to corrupt_images.txt")
# Out:
# Checking 16614 images...
#   0%|          | 0/16614 [00:00<?, ?it/s]
# 100%|██████████| 16614/16614 [29:41<00:00,  9.32it/s]
# --- RESULT ---
# All images loaded and decoded successfully.

# %% [markdown]
# ## Update Supabase (adjust as necessary)

# %%
# CONFIG
load_dotenv()

SUPABASE_URL = "https://utwhgfveotpusdjopcnl.supabase.co/"
SUPABASE_KEY = os.environ["SUPABASE_SERVICE_ROLE"]
BUCKET_NAME = "prolific_images"

# %%
# Objects to update, adjust as needed
IMAGE_PRIORS_OBJECTS = [
    "Rottweiler",
    "Sealyham terrier",
    "curly-coated retriever",
    "dalmatian",
    "espresso maker",
    "flat-coated retriever",
    "flute",
    "radio",
    "screw",
    "strainer",
    "typewriter",
    "van",
    "waffle iron",
]

COUNTERFACT_OBJECTS = [
    "Band Aid",
    "French horn",
    "Pomeranian",
    "car wheel",
    "faucet",
    "fridge",
    "limousine",
    "padlock",
    "plastic bag",
    "saxophone",
    "thimble",
    "truck",
    "trumpet",
    "wagon",
]

# %%
# Paths
IMAGE_PRIORS_ROOT = LOCAL_IMAGE_ROOT / "color_images/gpt-4o/image_priors"
COUNTERFACT_ROOT = LOCAL_IMAGE_ROOT / "color_images/gpt-4o/counterfact"

MAX_RETRIES = 6
SLEEP_BETWEEN_UPLOADS = 0.15
RETRY_SLEEP = 3.0
WRITE_ERROR_SLEEP = 5.0


# SUPABASE CLIENT
def make_supabase():
    return create_client(SUPABASE_URL, SUPABASE_KEY)

supabase = make_supabase()


# HELPERS
def normalize_object_name(name: str) -> str:
    return name.lower().replace(" ", "_")

def collect_object_folders(root: Path, object_names):
    folders = []
    wanted = {normalize_object_name(o) for o in object_names}

    for d in root.iterdir():
        if not d.is_dir():
            continue

        folder_prefix = d.name.lower()
        for obj in wanted:
            if folder_prefix.startswith(obj):
                folders.append(d)
                break

    return folders

# %%
# COLLECT FILES
folders_to_update = []

folders_to_update += collect_object_folders(
    IMAGE_PRIORS_ROOT, IMAGE_PRIORS_OBJECTS
)
folders_to_update += collect_object_folders(
    COUNTERFACT_ROOT, COUNTERFACT_OBJECTS
)

if not folders_to_update:
    raise RuntimeError("No folders found to update — check object names.")

image_paths = []

for folder in folders_to_update:
    for img in sorted(folder.glob("*.png")):
        rel_path = img.relative_to(LOCAL_IMAGE_ROOT)
        image_paths.append(rel_path)

print(f"Overwriting {len(image_paths)} images")
print("Folders:")
for f in folders_to_update:
    print(" -", f)


# UPLOAD (OVERWRITE)
for i, rel_path in enumerate(image_paths, 1):
    local_path = LOCAL_IMAGE_ROOT / rel_path

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            with open(local_path, "rb") as f:
                supabase.storage.from_(BUCKET_NAME).update(
                    path=str(rel_path),
                    file=f,
                    file_options={"content-type": "image/png"},
                )

            print(f"[{i}/{len(image_paths)}] Updated {rel_path}")
            break

        except WriteError:
            print(f"WriteError ({attempt}/{MAX_RETRIES}) → resetting client")
            supabase = make_supabase()
            time.sleep(WRITE_ERROR_SLEEP)

        except (RemoteProtocolError, ReadTimeout):
            print(f"Network error ({attempt}/{MAX_RETRIES}) on {rel_path}")
            time.sleep(RETRY_SLEEP)

        except Exception:
            raise

    time.sleep(SLEEP_BETWEEN_UPLOADS)

print("Done.")
# Out:
# Overwriting 63 images
# Folders:
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/radio_3_4d87b11a_resized_red
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/Rottweiler_4_131e8b4b_resized_brown
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/typewriter_4_0a946944_resized_grey
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/flat-coated_retriever_3_52e2a611_resized_brown
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/espresso_maker_2_fd91d5b6_resized_red
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/dalmatian_2_266c20b5_resized_grey
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/screw_2_f5051efb_resized_grey
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/Sealyham_terrier_1_be54a4a0_resized_grey
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/flute_2_ce750eec_resized_brown
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/van_1_74c49701_resized_blue
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/curly-coated_retriever_2_2190a917_resized_brown
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/strainer_4_c5445557_resized_blue
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/image_priors/waffle_iron_1_2f147e81_resized_red
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/limousine_3_22cb99c7_resized_purple
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/French_horn_1_961d420b_resized_red
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/car_wheel_2_0f5627b5_resized_yellow
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/thimble_4_d96ac4c9_resized_blue
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/Band_Aid_1_e73eed92_resized_purple
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/saxophone_3_638419c6_resized_red
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/wagon_4_24867bc8_resized_orange
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/padlock_2_b9f804e5_resized_red
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/truck_2_1ea04782_resized_purple
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/plastic_bag_1_60b6235f_resized_pink
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/fridge_5_c95cbde9_resized_yellow
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/Pomeranian_1_be789852_resized_blue
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/trumpet_2_a3181014_resized_blue
#  - /mnt/lustre/work/eickhoff/esx061/color-concept-entanglement/data/color_images/gpt-4o/counterfact/faucet_1_d53206b7_resized_pink
# Storage endpoint URL should have a trailing slash.
# [1/63] Updated color_images/gpt-4o/counterfact/Rottweiler_4_131e8b4b_resized_pink/BG_055_seq.png
# [2/63] Updated color_images/gpt-4o/counterfact/Rottweiler_4_131e8b4b_resized_pink/FG_055_seq.png
# [3/63] Updated color_images/gpt-4o/counterfact/Sealyham_terrier_1_be54a4a0_resized_purple/BG_055_seq.png
# [4/63] Updated color_images/gpt-4o/counterfact/Sealyham_terrier_1_be54a4a0_resized_purple/FG_055_seq.png
# [5/63] Updated color_images/gpt-4o/counterfact/espresso_maker_2_fd91d5b6_resized_pink/BG_055_seq.png
# [6/63] Updated color_images/gpt-4o/counterfact/espresso_maker_2_fd91d5b6_resized_pink/FG_055_seq.png
# [7/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_000_seq.png
# [8/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_005_seq.png
# [9/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_010_seq.png
# [10/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_020_seq.png
# [11/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_030_seq.png
# [12/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_040_seq.png
# [13/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_050_seq.png
# [14/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_055_seq.png
# [15/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_060_seq.png
# [16/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_070_seq.png
# [17/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_080_seq.png
# [18/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_090_seq.png
# [19/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/BG_100_seq.png
# [20/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_000_seq.png
# [21/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_005_seq.png
# [22/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_010_seq.png
# [23/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_020_seq.png
# [24/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_030_seq.png
# [25/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_040_seq.png
# [26/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_050_seq.png
# [27/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_055_seq.png
# [28/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_060_seq.png
# [29/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_070_seq.png
# [30/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_080_seq.png
# [31/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_090_seq.png
# [32/63] Updated color_images/gpt-4o/counterfact/flute_2_ce750eec_resized_orange/FG_100_seq.png
# [33/63] Updated color_images/gpt-4o/counterfact/great_white_shark_4_c223edfe_resized_red/FG_020_seq.png
# [34/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_000_seq.png
# [35/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_005_seq.png
# [36/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_010_seq.png
# [37/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_020_seq.png
# [38/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_030_seq.png
# [39/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_040_seq.png
# [40/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_050_seq.png
# [41/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_055_seq.png
# [42/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_060_seq.png
# [43/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_070_seq.png
# [44/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_080_seq.png
# [45/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_090_seq.png
# [46/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/BG_100_seq.png
# [47/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_000_seq.png
# [48/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_005_seq.png
# [49/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_010_seq.png
# [50/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_020_seq.png
# [51/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_030_seq.png
# [52/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_040_seq.png
# [53/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_050_seq.png
# [54/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_055_seq.png
# [55/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_060_seq.png
# [56/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_070_seq.png
# [57/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_080_seq.png
# [58/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_090_seq.png
# [59/63] Updated color_images/gpt-4o/counterfact/plunger_5_eca725f5_resized_blue/FG_100_seq.png
# [60/63] Updated color_images/gpt-4o/counterfact/radio_3_4d87b11a_resized_green/BG_055_seq.png
# [61/63] Updated color_images/gpt-4o/counterfact/radio_3_4d87b11a_resized_green/FG_055_seq.png
# [62/63] Updated color_images/gpt-4o/counterfact/strainer_4_c5445557_resized_green/BG_055_seq.png
# [63/63] Updated color_images/gpt-4o/counterfact/strainer_4_c5445557_resized_green/FG_055_seq.png
# Done.
